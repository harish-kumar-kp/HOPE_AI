# %%
#print Statement
print("HOPE AI")
# Out:
# HOPE AI

# %%
# user input
StringInput = input("Enter your institute name? :")
print("Enter your institute name? :",StringInput)
# Out:
# Enter your institute name? : HOPE AI

# %%
#Buy inputs
name = input("Enter your name:")
age = input("Enter your age:")
schoolName = input("Enter your school name:")
degree = input("Enter your drgree:")
print("Enter your name:",name)
print("Enter your age:",age)
print("Enter your school name:",schoolName)
print("Enter your drgree:",degree)
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name:  Guru school
# Enter your drgree:  B.E CSE

# %%
#Addition using 2 values in single input with space between them
a,b = input("values").split()
add = int(a) + int(b)
print("a=",a)
print("b=",b)
print("add =",add)
# Out:
# a= 43
# b= 34
# add = 77

# %%
#Addition
a = int(input("a="))
b = int (input("b="))
add = a + b
print("a=",a)
print("b=",add)
print("add =",add)
# Out:
# a= 43
# b= 77
# add = 77

# %%
#Subtraction
a = int(input("a="))
b = int (input("b="))
Sub = a - b
print("a=",a)
print("b=",b)
print("Sub =",Sub)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
#Multiplication
a = int(input("a="))
b = int (input("b="))
Mul = a * b
print("a=",a)
print("b=",b)
print("Mul =",Mul)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
#Division
a = int(input("a="))
b = int (input("b="))
Div = a / b
print("a=",a)
print("b=",b)
print("Float Div =",float(Div))
# Out:
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
#Floor division
a = int(input("a="))
b = int (input("b="))
Floordiv = a // b
print("a=",a)
print("b=",b)
print("Floor Div =",Floordiv)
# Out:
# a= 76
# b= 31
# Floor Div = 2

# %%
#Modulo
a = int(input("a="))
b = int (input("b="))
modulo = a % b
print("a=",a)
print("b=",b)
print("Modulo =",modulo)
# Out:
# a= 76
# b= 31
# Modulo = 14

# %%
#Power
a = int(input("a="))
b = int (input("b="))
power = a ** b
print("a=",a)
print("b=",b)
print("Power =",power)
# Out:
# a= 4
# b= 4
# Power = 256
