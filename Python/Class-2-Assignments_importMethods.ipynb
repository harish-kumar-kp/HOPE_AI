# %%
from multipleFunction import multipleFunction

# %%
myList = ["Machine Learning","Neural Networks","Vision","Robotics","Speech Processing","Natural Language Processing"]
multipleFunction.Subfields(myList)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
OddEven = multipleFunction.OddEven()
# Out:
# 52452 is Even number

# %%
ElegiblityForMarriage = multipleFunction.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# Not Eligible

# %%
FindPercent = multipleFunction.percentage(98,87,95,95,93)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.599999999999994

# %%
triangle = multipleFunction.triangle()
# Out:
# Height: 32
# Breadth: 32
# Area formula: (Height*Breadth)/2
# Area of Traingle: 512.0
# Height1: 2
# Height2: 4
# Breadth 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Traingle: 10
